# %%
import csv

# %%
import numpy as np
import pandas as pd
import collections
import re

# %%
file = open("reddit_database.csv")
reader = csv.reader(file)

# %%
rows = []
for row in reader:
    rows.append(row)

# %%
#rows

# %%
data = []
data_text = []
data_time = []
d1 = datetime(2011, 1, 3)
for row in rows[1:]:
    time1 = datetime.strptime(row[0], '%Y-%m-%d %H:%M:%S').date()
    if time1<d1.date():
        data.append([row[0], row[3]+' '+ row[12]])
        data_text.append(row[3]+' '+ row[12])
        data_time.append(time1)

# %%
#len(data_time)
# Out:
# 1790

# %%
#data_time
from datetime import datetime
datetime_object = datetime.strptime(data_time[0], '%Y-%m-%d %H:%M:%S')
print(datetime_object)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-79-7a0365830547> in <module>
#       1 #data_time
#       2 from datetime import datetime
# ----> 3 datetime_object = datetime.strptime(data_time[0], '%Y-%m-%d %H:%M:%S')
#       4 print(datetime_object)
#
# TypeError: strptime() argument 1 must be str, not datetime.date

# %%
for i in range(len(data_text)):
    data_text[i] = re.sub(r"[^a-zA-Z]", " ", data_text[i].lower())

data_text
# Out:
# ['youtube s traffic data for music questioned ',
#  'november sees number of u s  videos viewed online surpass    billion for first time on record  comscore  ',
#  'so what do you guys all do related to analytics  why the interest  there s a lot of reasons to want to know all this stuff  so i figured i d get to know the others that are on this subreddit   so let s hear it  webmasters  coders  marketers  work for an analytics software company  you get the idea ',
#  '   web analytics tools for tracking your visitors ',
#  'improving your sense of site ',
# ...

# %%
len(data_text)
# Out:
# 545427

# %%
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

# %%
from sklearn.feature_extraction.text import CountVectorizer
#vectorizer = CountVectorizer(stop_words='english')
vectorizer = CountVectorizer(stop_words='english',ngram_range=(2,2))
X = vectorizer.fit_transform(data_text[:10000])
df_bow_sklearn = pd.DataFrame(X.toarray(),columns=vectorizer.get_feature_names())
#df_bow_sklearn.head(20)

# %%
r = pd.DataFrame(df_bow_sklearn.sum())

# %%
r.sort_values(by = [0], ascending = False).head(50)
# Out:
#                            0
# machine learning         173
# http www                  69
# data mining               55
# time series               35
# stats cats                30
# cats blog                 30
# artificial intelligence   21
# ask stats                 19
# open source               19
# data analysis             19
# data set                  18
# don know                  17
# imgur com                 16
# reinforcement learning    16
# need help                 16
# data sets                 15
# standard deviation        14
# neural networks           13
# does know                 13
# reddit com                13
# sample size               13
# http en                   12
# wikipedia org             12
# ask statistics            12
# want know                 12
# http imgur                12
# neural network            12
# en wikipedia              12
# linear regression         12
# statistical analysis      11
# ask ml                    11
# ...
